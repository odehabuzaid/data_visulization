# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_Dogecoin = pd.read_csv('./input/coin_Dogecoin.csv')
df_bitcoin = pd.read_csv('./input/coin_Bitcoin.csv')

# %%
df_bitcoin
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
custom_colors = ["#4e89ae", "#c56183","#ed6663","#ffa372"]

# %%
def triple_plot(x, title,c):
    fig, ax = plt.subplots(3,1,figsize=(25,10),sharex=True)
    sns.distplot(x, ax=ax[0],color=c)
    ax[0].set(xlabel=None)
    ax[0].set_title('Histogram + KDE')
    sns.histplot(x, ax=ax[1],color=c)
    ax[1].set(xlabel=None)
    ax[1].set_title('Histplot')
    sns.violinplot(x, ax=ax[2],color=c)
    ax[2].set(xlabel=None)
    ax[2].set_title('Violin plot')
    fig.suptitle(title, fontsize=30)
    plt.tight_layout(pad=3.0)
    plt.show()

# %%
triple_plot(df_bitcoin['Open'],'Distribution of Opening price in USD of bitcoin 2013 - 2021',custom_colors[0])
# Out:
# C:\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_Dogecoin.head()
# Out:
#    SNo      Name Symbol                 Date      High       Low      Open  \
# 0    1  Dogecoin   DOGE  2013-12-16 23:59:59  0.000866  0.000150  0.000299
# 1    2  Dogecoin   DOGE  2013-12-17 23:59:59  0.000289  0.000116  0.000207
# 2    3  Dogecoin   DOGE  2013-12-18 23:59:59  0.000362  0.000205  0.000267
# 3    4  Dogecoin   DOGE  2013-12-19 23:59:59  0.001520  0.000328  0.000395
# 4    5  Dogecoin   DOGE  2013-12-20 23:59:59  0.001143  0.000662  0.001143
#
#       Close  Volume     Marketcap
# 0  0.000205     0.0  1.509085e+06
# 1  0.000269     0.0  2.169688e+06
# 2  0.000362     0.0  3.188943e+06
# 3  0.001162     0.0  1.115034e+07
# 4  0.000704     0.0  7.284337e+06

# %%
df_bitcoin.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
labels = list(df_bitcoin['Date'])
last_seen = ['2021']
index = [0]
for i in range(len(labels)):
    labels[i] = labels[i].split('-')[0]
    if labels[i] != last_seen[-1]:
        last_seen.append(labels[i])
        index.append(i)

plt.plot(df_bitcoin['High'], label='Bitcoin High Price')
plt.plot(df_bitcoin['Low'], label='Bitcoin Low Price')
plt.plot(df_bitcoin['Open'], label='Bitcoin Open Price')
plt.plot(df_bitcoin['Marketcap'], label='Bitcoin Market Cap')


plt.plot(df_Dogecoin['High'], label='Dogecoin High Price')
plt.plot(df_Dogecoin['Low'], label='Dogecoin Close Price')
plt.plot(df_Dogecoin['Open'], label='Dogecoin Open Price')
plt.plot(df_Dogecoin['Marketcap'], label='Dogecoin Market Cap')


plt.gca().set_yscale("log")
plt.yticks([])
plt.xticks(index, last_seen)
plt.xlabel('Year', labelpad=20)
plt.gcf().set_size_inches(15, 10)
plt.legend()
plt.suptitle('Bitcoin Vs Doogie coin   Open , High Low comparsion', fontsize=30)
plt.tight_layout(pad=3.0)
plt.show()

# %%
df_bitcoin.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
seed=42 # random seed for reproductibility

# split data into train and validation
x = df_bitcoin[['High']].values
y = df_bitcoin.iloc[:, 0].values

x_train, x_val, y_train, y_val = train_test_split(x,y,test_size=0.40,random_state=40)
print(f"X_train shape {x_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_test shape {x_val.shape}")
print(f"y_test shape {y_val.shape}")
# Out:
# X_train shape (1794, 1)
# y_train shape (1794,)
# X_test shape (1197, 1)
# y_test shape (1197,)

# %%
lm = LinearRegression()
lm.fit(x_train,y_train)
y_predict = lm.predict(x_val)
print(f"Train accuracy {round(lm.score(x_train,y_train)*100,2)} %")
print(f"Test accuracy {round(lm.score(x_val,y_val)*100,2)} %")
# Out:
# Train accuracy 43.78 %
# Test accuracy 45.48 %

# %%
plt.plot(df_bitcoin['Close'], label='Closing Price Price (USD)')
plt.plot(lm.predict(x), label='Prediction')
plt.gca().set_yscale("log")
plt.xticks(index, last_seen)
plt.xlabel('Year', labelpad=20)
plt.gcf().set_size_inches(15, 10)
plt.legend()
plt.show()

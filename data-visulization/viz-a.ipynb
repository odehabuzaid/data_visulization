# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset("titanic")

# %%
g = sns.catplot(x="class", y="survived", hue="sex", data=titanic, kind="bar")

# %%
sns.catplot(x="age", y="survived", hue="alive", data=titanic)
